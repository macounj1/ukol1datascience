# %% [markdown]
# ## Hello there

# %% [markdown]
# Načtení dat & inicializace

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from random import sample

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score
from sklearn import tree
from sklearn.ensemble import RandomForestRegressor

import CHAID

pd.set_option('mode.chained_assignment',None)

# %%
# Import dataset

#JÁRA načtení tam kde to mám uložené
data = pd.read_csv('C:/Users/macou/OneDrive/Dokumenty/ukol1datascience/hw1_devsample.csv', encoding='utf-8')

#FANDOVO načtení dat
#data_all = pd.read_csv('.../hw1_devsample.csv', encoding='utf-8')

print(f'Number of rows:      {data.shape[0]}')
print(f'Number of columns:   {data.shape[1]}')
# Out:
# Number of rows:      80000
# Number of columns:   197

# %%
#kaggle competitions download -c mff-data-science-2-hw1
#nejde mi to pomoci tohoto nahrát tak jsem to udělal ručně
for col in data.columns:
    print(col)
# Out:
# SK_ID_CURR
# TARGET
# NAME_CONTRACT_TYPE
# CODE_GENDER
# FLAG_OWN_CAR
# FLAG_OWN_REALTY
# CNT_CHILDREN
# AMT_INCOME_TOTAL
# AMT_CREDIT
# AMT_ANNUITY
# AMT_GOODS_PRICE
# NAME_TYPE_SUITE
# NAME_INCOME_TYPE
# NAME_EDUCATION_TYPE
# NAME_FAMILY_STATUS
# NAME_HOUSING_TYPE
# REGION_POPULATION_RELATIVE
# DAYS_BIRTH
# DAYS_EMPLOYED
# DAYS_REGISTRATION
# DAYS_ID_PUBLISH
# OWN_CAR_AGE
# FLAG_MOBIL
# FLAG_EMP_PHONE
# FLAG_WORK_PHONE
# FLAG_CONT_MOBILE
# FLAG_PHONE
# FLAG_EMAIL
# OCCUPATION_TYPE
# CNT_FAM_MEMBERS
# REGION_RATING_CLIENT
# REGION_RATING_CLIENT_W_CITY
# WEEKDAY_APPR_PROCESS_START
# HOUR_APPR_PROCESS_START
# REG_REGION_NOT_LIVE_REGION
# REG_REGION_NOT_WORK_REGION
# LIVE_REGION_NOT_WORK_REGION
# REG_CITY_NOT_LIVE_CITY
# REG_CITY_NOT_WORK_CITY
# LIVE_CITY_NOT_WORK_CITY
# ORGANIZATION_TYPE
# EXT_SOURCE_1
# EXT_SOURCE_2
# EXT_SOURCE_3
# APARTMENTS_AVG
# BASEMENTAREA_AVG
# YEARS_BEGINEXPLUATATION_AVG
# YEARS_BUILD_AVG
# COMMONAREA_AVG
# ELEVATORS_AVG
# ENTRANCES_AVG
# FLOORSMAX_AVG
# ...

# %% [markdown]
# hodně sloupců na výběr prediktorů

# %%
for col in data.columns:
    print(col,data[col].dtypes)
# Out:
# SK_ID_CURR int64
# TARGET float64
# NAME_CONTRACT_TYPE object
# CODE_GENDER object
# FLAG_OWN_CAR object
# FLAG_OWN_REALTY object
# CNT_CHILDREN float64
# AMT_INCOME_TOTAL float64
# AMT_CREDIT float64
# AMT_ANNUITY float64
# AMT_GOODS_PRICE float64
# NAME_TYPE_SUITE object
# NAME_INCOME_TYPE object
# NAME_EDUCATION_TYPE object
# NAME_FAMILY_STATUS object
# NAME_HOUSING_TYPE object
# REGION_POPULATION_RELATIVE float64
# DAYS_BIRTH float64
# DAYS_EMPLOYED int64
# DAYS_REGISTRATION float64
# DAYS_ID_PUBLISH int64
# OWN_CAR_AGE float64
# FLAG_MOBIL int64
# FLAG_EMP_PHONE int64
# FLAG_WORK_PHONE int64
# FLAG_CONT_MOBILE int64
# FLAG_PHONE int64
# FLAG_EMAIL int64
# OCCUPATION_TYPE object
# CNT_FAM_MEMBERS float64
# REGION_RATING_CLIENT int64
# REGION_RATING_CLIENT_W_CITY int64
# WEEKDAY_APPR_PROCESS_START object
# HOUR_APPR_PROCESS_START int64
# REG_REGION_NOT_LIVE_REGION int64
# REG_REGION_NOT_WORK_REGION int64
# LIVE_REGION_NOT_WORK_REGION int64
# REG_CITY_NOT_LIVE_CITY int64
# ...

# %%
for col in data.columns:
    if data[col].dtypes=='object' :
        print(col)
        print(data[col].value_counts())
        print('===================================')
        print('-----------------------------------')
# Out:
# NAME_CONTRACT_TYPE
# Cash loans         72366
# Revolving loans     7634
# Name: NAME_CONTRACT_TYPE, dtype: int64
# ...
# -----------------------------------
# CODE_GENDER
# F      52488
# M      27510
# XNA        2
# Name: CODE_GENDER, dtype: int64
# ...
# -----------------------------------
# FLAG_OWN_CAR
# N    52682
# Y    27318
# Name: FLAG_OWN_CAR, dtype: int64
# ...
# -----------------------------------
# FLAG_OWN_REALTY
# Y    55485
# N    24515
# Name: FLAG_OWN_REALTY, dtype: int64
# ...
# -----------------------------------
# NAME_TYPE_SUITE
# Unaccompanied      64664
# Family             10371
# Spouse, partner     3033
# Children             853
# Other_B              436
# Other_A              220
# Group of people       70
# Name: NAME_TYPE_SUITE, dtype: int64
# ...
# -----------------------------------
# NAME_INCOME_TYPE
# Working                 41321
# Commercial associate    18699
# Pensioner               14365
# State servant            5602
# Student                     8
# ...

# %% [markdown]
# U všech typu object se mi zdá nepoužitelný: WEEKDAY_APPR_PROCESS_START, TIME

# %% [markdown]
#  zajímají nás jen některé sloupce, OTÁZKA KTERÉ NAPSAL JSEM JEN PRVNÍCH 10

# %%
columns = ["SK_ID_CURR", "TARGET", "NAME_CONTRACT_TYPE", "CODE_GENDER", "FLAG_OWN_CAR", "FLAG_OWN_REALTY", "CNT_CHILDREN", "AMT_INCOME_TOTAL", "AMT_CREDIT", "AMT_ANNUITY"
          ,"AMT_GOODS_PRICE"]

# %%
data.head()
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0      215138     0.0         Cash loans           M            N
# 1      325963     0.0         Cash loans           M            Y
# 2      206923     0.0         Cash loans           F            N
# 3      265855     0.0         Cash loans           F            N
# 4      359795     0.0    Revolving loans           F            N
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0               Y           0.0          135000.0    646920.0      25195.5
# 1               Y           0.0          135000.0    740218.5      40284.0
# 2               Y           0.0          180000.0    339241.5      12919.5
# 3               Y           0.0          180000.0   1264428.0      37098.0
# 4               Y           NaN           76500.0    202500.0      10125.0
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
# ...

# %% [markdown]
#  zdá se že chybějící NaN hodnoty budou jen u CNT_children

# %% [markdown]
# # CART metoda

# %%
data_cart = data.copy()

# %%
data_cart=data_cart[columns]

# %%
data_cart.isna().sum()
# Out:
# SK_ID_CURR                0
# TARGET                    0
# NAME_CONTRACT_TYPE        0
# CODE_GENDER               0
# FLAG_OWN_CAR              0
# FLAG_OWN_REALTY           0
# CNT_CHILDREN          24965
# AMT_INCOME_TOTAL          0
# AMT_CREDIT                0
# AMT_ANNUITY               6
# AMT_GOODS_PRICE          63
# dtype: int64

# %%
data_cart["CNT_CHILDREN"].value_counts()
# Out:
# 0.0     41680
# 1.0      9352
# 2.0      3562
# 3.0       399
# 4.0        32
# 5.0         6
# 6.0         1
# 12.0        1
# 10.0        1
# 8.0         1
# Name: CNT_CHILDREN, dtype: int64

# %%
#zdá se že by chybějící hodnota mohla znamenat 0 dětí anebo doopravdy chybějící hodnota


#nahrazení výběrovým průměrem + zamyslet jestli nevzít radši median když j epotřeba aby to byla celočíselná hodnota
#data_cart=data_cart.fillna(data_cart.mean())

#nahrazení hodnotou 0
data_cart["CNT_CHILDREN"]=data_cart["CNT_CHILDREN"].fillna(0)
data_cart=data_cart.fillna(data_cart.mean())

# %%
data_cart.value_counts()
# Out:
# SK_ID_CURR  TARGET  NAME_CONTRACT_TYPE  CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  AMT_GOODS_PRICE
# 456251      0.0     Cash loans          M            N             N                0.0           157500.0          254700.0    27558.0      225000.0           1
# 219092      0.0     Cash loans          M            N             Y                0.0           135000.0          871029.0    44604.0      765000.0           1
# 219053      0.0     Cash loans          F            N             Y                0.0           135000.0          254700.0    18585.0      225000.0           1
# 219061      0.0     Revolving loans     M            Y             Y                0.0           202500.0          405000.0    20250.0      405000.0           1
# 219067      1.0     Cash loans          F            N             Y                1.0           180000.0          1288350.0   37800.0      1125000.0          1
# ...

# %%
data_cart.dtypes
# Out:
# SK_ID_CURR              int64
# TARGET                float64
# NAME_CONTRACT_TYPE     object
# CODE_GENDER            object
# FLAG_OWN_CAR           object
# FLAG_OWN_REALTY        object
# CNT_CHILDREN          float64
# AMT_INCOME_TOTAL      float64
# AMT_CREDIT            float64
# AMT_ANNUITY           float64
# AMT_GOODS_PRICE       float64
# dtype: object

# %%
# Re-encode. Column 'Date' will not be used for prediction, therefore, no need to encode it. Only 'RainToday' and 'RainTomorrow' should be re-encoded.

# TODO: Convert values of 'RainToday' and 'RainTomorrow' into 0-1 encoding. You can use .apply function to use row-by-row notation.
data_cart['NAME_CONTRACT_FLAG']=data_cart['NAME_CONTRACT_TYPE'].apply(lambda x: 1 if x=='Cash loans' else 0) #(TODO)
data_cart['CODE_GENDER_FLAG']=data_cart['CODE_GENDER'].apply(lambda x: 1 if x=='M' else 0) #(TODO)
data_cart['FLAG_OWN_CAR_FLAG']=data_cart['FLAG_OWN_CAR'].apply(lambda x: 1 if x=='Y' else 0) #(TODO)
data_cart['FLAG_OWN_REALTY_FLAG']=data_cart['FLAG_OWN_REALTY'].apply(lambda x: 1 if x=='Y' else 0) #(TODO)

# %%
target = 'TARGET'

predictors = columns.copy()
predictors.remove('SK_ID_CURR')
predictors.remove('NAME_CONTRACT_TYPE')
predictors.remove('CODE_GENDER')
predictors.remove('FLAG_OWN_CAR')
predictors.remove('FLAG_OWN_REALTY')
predictors.remove('TARGET')
predictors += ["NAME_CONTRACT_FLAG"]
predictors += ["CODE_GENDER_FLAG"]
predictors += ["FLAG_OWN_CAR_FLAG"]
predictors += ["FLAG_OWN_REALTY_FLAG"]

# %%
predictors
# Out:
# ['CNT_CHILDREN',
#  'AMT_INCOME_TOTAL',
#  'AMT_CREDIT',
#  'AMT_ANNUITY',
#  'AMT_GOODS_PRICE',
#  'NAME_CONTRACT_FLAG',
#  'CODE_GENDER_FLAG',
#  'FLAG_OWN_CAR_FLAG',
#  'FLAG_OWN_REALTY_FLAG']

# %% [markdown]
# ## ROZDĚLENÍ NA  TRAIN  & TEST DATASET

# %%
pd.to_datetime(data['TIME'])
# Out:
# 0       2018-06-23
# 1       2018-06-16
# 2       2018-06-19
# 3       2018-08-09
# 4       2018-11-13
#            ...
# 79995   2018-04-20
# 79996   2018-09-08
# 79997   2018-02-15
# 79998   2018-06-27
# 79999   2018-05-16
# Name: TIME, Length: 80000, dtype: datetime64[ns]

# %%
data_cart['MONTH'] = pd.to_datetime(data['TIME']).dt.month
data_cart['MONTH'].value_counts()
# Out:
# 12    6892
# 1     6809
# 3     6805
# 5     6772
# 10    6745
# 6     6693
# 8     6664
# 9     6643
# 7     6629
# 11    6583
# 4     6511
# 2     6254
# Name: MONTH, dtype: int64

# %%
data_cart_train, data_cart_test = train_test_split(
    data_cart, test_size=0.1, random_state=17,stratify=data_cart['MONTH'])

# %%
criterion = 'gini' #(TODO)
splitter = 'best' #(TODO)
mdepth = 5 #(TODO)
min_samples_split = 20 #(TODO)
min_samples_leaf = 0.001 #(TODO)
minleaf = 30 #(TODO)
random_state = 17

# Now we contruct the model.
model = tree.DecisionTreeClassifier(
    criterion=criterion,
    splitter=splitter, 
    max_depth=mdepth,
    min_samples_split=min_samples_split,
    min_samples_leaf=min_samples_leaf, 
    random_state=random_state, 
)

# And fit training data.

clf = model.fit(data_cart_train[predictors], data_cart_train[target])

# %%
# Predict class labels on training data
pred_labels_tr = model.predict(data_cart_train[predictors])
# Predict class labels on a test data
pred_labels_te = model.predict(data_cart_test[predictors])

# %%
data_cart_train[target]
# Out:
# 26581    1.0
# 43107    0.0
# 33978    0.0
# 29499    1.0
# 3245     0.0
#         ...
# 43888    0.0
# 62853    0.0
# 10156    0.0
# 55947    0.0
# 61626    0.0
# Name: TARGET, Length: 72000, dtype: float64

# %%
data_cart_test[target]
# Out:
# 26804    0.0
# 20371    0.0
# 76996    0.0
# 31241    0.0
# 2610     0.0
#         ...
# 768      0.0
# 61674    0.0
# 31310    0.0
# 14815    0.0
# 40173    0.0
# Name: TARGET, Length: 8000, dtype: float64

# %%
# Tree summary and model evaluation metrics
print('*************** Tree Summary ***************')
print('Classes: ', clf.classes_)
print('Tree Depth: ', clf.tree_.max_depth)
print('No. of leaves: ', clf.tree_.n_leaves)
print('No. of features: ', clf.n_features_)
print('--------------------------------------------------------')
print("")

print('*************** Evaluation on Test Data ***************')
score_te = model.score(data_cart_test[predictors], data_cart_test[target])
print('Accuracy Score: ', score_te)
# Look at classification report to evaluate the model
print(classification_report(data_cart_test[target], pred_labels_te))
print('--------------------------------------------------------')
print("")

print('*************** Evaluation on Training Data ***************')
score_tr = model.score(data_cart_train[predictors], data_cart_train[target])
print('Accuracy Score: ', score_tr)
# Look at classification report to evaluate the model
print(classification_report(data_cart_train[target], pred_labels_tr))
print('--------------------------------------------------------')
# Out:
# *************** Tree Summary ***************
# Classes:  [0. 1.]
# Tree Depth:  5
# No. of leaves:  31
# No. of features:  9
# --------------------------------------------------------
#
# *************** Evaluation on Test Data ***************
# Accuracy Score:  0.920375
#               precision    recall  f1-score   support
#
#          0.0       0.92      1.00      0.96      7363
#          1.0       0.00      0.00      0.00       637
#
#     accuracy                           0.92      8000
#    macro avg       0.46      0.50      0.48      8000
# weighted avg       0.85      0.92      0.88      8000
#
# --------------------------------------------------------
#
# *************** Evaluation on Training Data ***************
# Accuracy Score:  0.9197361111111111
#               precision    recall  f1-score   support
#
#          0.0       0.92      1.00      0.96     66221
#          1.0       0.00      0.00      0.00      5779
#
# ...

# %%
fig, ax = plt.subplots(figsize=(25, 25))
tree.plot_tree(clf, ax=ax)
plt.show()

# %% [markdown]
# Nějak to furt predikuje nuly tak mi to je divné

# %%
# Get numerical feature importances
importances = list(clf.feature_importances_)
# List of tuples with variable and importance
feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(predictors, importances)]
# Sort the feature importances by most important first
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)
# Print out the feature and importances 
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances];
# Out:
# Variable: AMT_GOODS_PRICE      Importance: 0.36
# Variable: CODE_GENDER_FLAG     Importance: 0.2
# Variable: AMT_CREDIT           Importance: 0.19
# Variable: AMT_ANNUITY          Importance: 0.13
# Variable: FLAG_OWN_CAR_FLAG    Importance: 0.09
# Variable: NAME_CONTRACT_FLAG   Importance: 0.02
# Variable: AMT_INCOME_TOTAL     Importance: 0.01
# Variable: CNT_CHILDREN         Importance: 0.0
# Variable: FLAG_OWN_REALTY_FLAG Importance: 0.0

# %%
# Plot importance
x_values = list(range(len(importances)))
# Make a bar chart
plt.bar(x_values, importances, orientation = 'vertical')
# Tick labels for x axis
plt.xticks(x_values, predictors, rotation='vertical')
# Axis labels and title
plt.ylabel('Importance'); plt.xlabel('Variable'); plt.title('Variable Importances');

# %% [markdown]
# # Zde si jen zkouším co by to predikovalo na těch odevzdávacích datech {JÁRA}

# %%
data_finalvalid= pd.read_csv('C:/Users/macou/OneDrive/Dokumenty/ukol1datascience/hw1_outofsample.csv', encoding='utf-8')

# %%
data_finalvalid['NAME_CONTRACT_FLAG']=data_finalvalid['NAME_CONTRACT_TYPE'].apply(lambda x: 1 if x=='Cash loans' else 0) #(TODO)
data_finalvalid['CODE_GENDER_FLAG']=data_finalvalid['CODE_GENDER'].apply(lambda x: 1 if x=='M' else 0) #(TODO)
data_finalvalid['FLAG_OWN_CAR_FLAG']=data_finalvalid['FLAG_OWN_CAR'].apply(lambda x: 1 if x=='Y' else 0) #(TODO)
data_finalvalid['FLAG_OWN_REALTY_FLAG']=data_finalvalid['FLAG_OWN_REALTY'].apply(lambda x: 1 if x=='Y' else 0) #(TODO)

# %%
data_finalvalid["CNT_CHILDREN"]=data_finalvalid["CNT_CHILDREN"].fillna(0)
data_finalvalid=data_finalvalid.fillna(data_cart.mean())

# %%
prediction_final = model.predict(data_finalvalid[predictors])

# %%
prediction_final.sum()
# Out:
# 0.0
